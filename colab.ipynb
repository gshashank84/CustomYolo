# %% [markdown]
# <a href="https://colab.research.google.com/github/gshashank84/CustomYolo/blob/master/colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('train.txt','w') as df:
  started = 'data/img/test_00000000'
  last= '00001007'
  io = '0000'
  jpg = '.jpg'
  for i in range(1,990):
    name = str(i)
    name2 = io[len(name):]+str(i)
    final_name = 'data/img/test_0000'+name2+jpg+'\n'
    df.write(final_name)

# %%
with open('train.txt','r') as bf:
  print(bf.read())
# Out:
# data/img/test_00000001.jpg
# data/img/test_00000002.jpg
# data/img/test_00000003.jpg
# data/img/test_00000004.jpg
# data/img/test_00000005.jpg
# data/img/test_00000006.jpg
# data/img/test_00000007.jpg
# data/img/test_00000008.jpg
# data/img/test_00000009.jpg
# data/img/test_00000010.jpg
# data/img/test_00000011.jpg
# data/img/test_00000012.jpg
# data/img/test_00000013.jpg
# data/img/test_00000014.jpg
# data/img/test_00000015.jpg
# data/img/test_00000016.jpg
# data/img/test_00000017.jpg
# data/img/test_00000018.jpg
# data/img/test_00000019.jpg
# data/img/test_00000020.jpg
# data/img/test_00000021.jpg
# data/img/test_00000022.jpg
# data/img/test_00000023.jpg
# data/img/test_00000024.jpg
# data/img/test_00000025.jpg
# data/img/test_00000026.jpg
# data/img/test_00000027.jpg
# data/img/test_00000028.jpg
# data/img/test_00000029.jpg
# data/img/test_00000030.jpg
# data/img/test_00000031.jpg
# data/img/test_00000032.jpg
# data/img/test_00000033.jpg
# data/img/test_00000034.jpg
# ...

# %%
with open('test.txt','w') as df:
  started = 'data/img/test_00000000'
  last= '00001007'
  io = '0000'
  jpg = '.jpg'
  for i in range(990,1008):
    name = str(i)
    name2 = io[len(name):]+str(i)
    final_name = 'data/img/test_0000'+name2+jpg+'\n'
    df.write(final_name)

# %%
with open('test.txt','r') as bf:
  print(bf.read())
# Out:
# data/img/test_00000990.jpg
# data/img/test_00000991.jpg
# data/img/test_00000992.jpg
# data/img/test_00000993.jpg
# data/img/test_00000994.jpg
# data/img/test_00000995.jpg
# data/img/test_00000996.jpg
# data/img/test_00000997.jpg
# data/img/test_00000998.jpg
# data/img/test_00000999.jpg
# data/img/test_00001000.jpg
# data/img/test_00001001.jpg
# data/img/test_00001002.jpg
# data/img/test_00001003.jpg
# data/img/test_00001004.jpg
# data/img/test_00001005.jpg
# data/img/test_00001006.jpg
# data/img/test_00001007.jpg

# %%
# %%bash
# git clone https://github.com/pjreddie/darknet
# cd darknet
# make
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/gemm.c -o obj/gemm.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/cuda.c -o obj/cuda.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/deconvolutional_layer.c -o obj/deconvolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/list.c -o obj/list.o
# ...

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-04-21 16:50:22--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   313KB/s    in 13m 27s
#
# 2020-04-21 17:03:51 (300 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# %%bash
# cd darknet
# ./darknet detect cfg/yolov3.cfg yolov3.weights data/dog.jpg

# %%
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2020-04-21 17:08:20--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1  54%[=========>          ]  84.21M   464KB/s    eta 3m 17s

# %%
# %%bash
# cd darknet
# ./darknet detector train data/obj.data yolov3.cfg darknet53.conv.74
